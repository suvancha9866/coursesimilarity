# %%
import pandas as pd
df = pd.read_csv("course-catalog.csv")

# %%
df = pd.read_csv("course-catalog.csv")
df["Course"] = df['Subject'].astype(str) + " " + df['Number'].astype(str) 
df = df.drop_duplicates(subset=['Subject', 'Number'])
df = df[~df['Description'].str.startswith("Same as", na=False)]
df = df[~df["Description"].str.startswith("May be repeated", na=False)]
df = df[~df["Description"].str.startswith("Approved for S/U grading only.", na=False)]
df["Description"] = df["Description"].str.split("Approved for").str[0]
df["Description"] = df["Description"].str.split("May be repeated").str[0]
df["Description"] = df["Description"].str.split("Prerequisite:").str[0]
df["Description"] = df["Description"].str.split("Credit is not").str[0]
df["Description"] = df["Description"].str.split("Continuation of").str[0]
df["Description"] = df["Description"].str.replace(r"\b\d+\s*(or\s*\d+)?\s*(to\s*\d+)?\s*(undergraduate|graduate|professional)\s*hours\b", "", regex=True)
df = df[~df['Description'].str.match(r'^\s*$|^\.*$', na=True)]
df = df.drop_duplicates(subset=["Description"])

display(df)
# Out:
#        Year    Term YearTerm Subject  Number  \
# 0      2025  Spring  2025-sp     AAS     100
# 12     2025  Spring  2025-sp     AAS     200
# 15     2025  Spring  2025-sp     AAS     211
# 16     2025  Spring  2025-sp     AAS     215
# 21     2025  Spring  2025-sp     AAS     287
# ...     ...     ...      ...     ...     ...
# 12301  2025  Spring  2025-sp      VM     642
# 12302  2025  Spring  2025-sp      VM     645
# 12303  2025  Spring  2025-sp      VM     655
# 12307  2025  Spring  2025-sp      VM     656
# 12309  2025  Spring  2025-sp    WGGP     581
#
#                                         Name  \
# 0               Intro Asian American Studies
# 12                      U.S. Race and Empire
# 15              Asian Americans and the Arts
# 16              US Citizenship Comparatively
# 21                  Food and Asian Americans
# ...                                      ...
# 12301         Contemporary Issues in Vet Med
# 12302             Communications in Practice
# 12303  Small Animal Medicine and Surgery III
# 12307  Large Animal Medicine and Surgery III
# 12309        Gender Relations &amp; Intl Dev
#
#                                              Description Credit Hours  \
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 12     Invites students to examine histories and narr...     3 hours.
# 15     Examination of Asian American artistic express...     3 hours.
# 16     Examines the racial, gendered, and sexualized ...     3 hours.
# 21     Introduction to the interdisciplinary study of...     3 hours.
# ...                                                  ...          ...
# 12301  An introductory course that enables students t...     1 hours.
# 12302  An introductory course for third year veterina...     1 hours.
# 12303  Teaches the practice of Small Animal Medicine ...     7 hours.
# 12307  Teaches the practice of Large Animal Medicine ...   3.5 hours.
# 12309  Interdisciplinary seminar examining theoretica...     4 hours.
#
#                                             Section Info  \
# 0                                                    NaN
# 12                                      Same as LLS 200.
# 15     Prerequisite: AAS 100 or AAS 120, or consent o...
# 16      Same as AFRO 215, AIS 295, GWS 215, and LLS 215.
# 21     Prerequisite: AAS 100 or AAS 120, or consent o...
# ...                                                  ...
# 12301  No graduate credit. 1 professional hour. Appro...
# 12302  No graduate credit. 1 professional hour. Appro...
# 12303  No graduate credit. 7 professional hours. Prer...
# 12307  No graduate credit. 3.5 professional hours. Pr...
# 12309                      Same as GWS 512 and SOCW 581.
#
#                                        Degree Attributes  ...  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 12     Humanities - Hist & Phil, and Cultural Studies...  ...
# 15     Humanities - Lit & Arts, and Cultural Studies ...  ...
# 16     Humanities - Hist & Phil, and Cultural Studies...  ...
# 21     Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# ...                                                  ...  ...
# 12301                                                NaN  ...
# 12302                                                NaN  ...
# 12303                                                NaN  ...
# 12307                                                NaN  ...
# 12309                                                NaN  ...
#
#        Enrollment Status                Type Type Code Start Time  End Time  \
# 0                 Closed  Lecture-Discussion       LCD   02:00 PM  03:20 PM
# 12         CrossListOpen  Lecture-Discussion       LCD   12:30 PM  01:50 PM
# 15                  Open  Lecture-Discussion       LCD   03:30 PM  04:50 PM
# 16         CrossListOpen  Lecture-Discussion       LCD   11:00 AM  12:20 PM
# 21                  Open  Lecture-Discussion       LCD   02:00 PM  03:20 PM
# ...                  ...                 ...       ...        ...       ...
# 12301  Open (Restricted)  Lecture-Discussion       LCD   04:00 PM  04:50 PM
# 12302  Open (Restricted)  Lecture-Discussion       LCD   03:00 PM  04:50 PM
# 12303               Open          Laboratory       LAB   08:00 AM  11:50 AM
# 12307               Open          Laboratory       LAB   11:00 AM  11:50 AM
# 12309             Closed  Lecture-Discussion       LCD   02:00 PM  04:50 PM
#
#       Days of Week Room                       Building  \
# 0               MW  304               Noyes Laboratory
# 12              TR  148                         Armory
# 15              TR  G18  Literatures, Cultures, & Ling
# 16              TR  207            Psychology Building
# 21              TR  137      Henry Administration Bldg
# ...            ...  ...                            ...
# 12301           MT  NaN                            NaN
# 12302            M  NaN                            NaN
# 12303            T  NaN                            NaN
# 12307          MWF  NaN                            NaN
# 12309            R  131               English Building
#
#                                              Instructors    Course
# 0                                                Geng, C   AAS 100
# 12                                             Sawada, E   AAS 200
# 15                                             Sawada, E   AAS 211
# 16                                             Siglos, D   AAS 215
# 21                                               Kang, S   AAS 287
# ...                                                  ...       ...
# 12301                                         Desmond, J    VM 642
# 12302                                         Garrett, L    VM 645
# 12303     Cappa, T;Elston, C;Foreman, J;Foss, K;Hague, D    VM 655
# 12307  Aldridge, R;Austin, S;Foreman, J;French, D;Gar...    VM 656
# 12309                                        Fogelman, C  WGGP 581
#
# [3772 rows x 28 columns]
